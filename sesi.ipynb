# %%
harga = 100000
diskon = 20
print("Harga awal:", harga)
print("Diskon:", diskon)

total = harga - (harga*diskon/100)
print("Total Harga:", total)
# Out:
# Harga awal: 100000
# Diskon: 20
# Total Harga: 80000.0

# %%
angka = 10
diskon = 20

breakpoint()

hasil = angka * diskon

print(hasil)
# Out:
# --Return--
# None
# > /tmp/ipykernel_1242/2372346830.py(4)<cell line: 0>()
#       2 diskon = 20
#       3
# ----> 4 breakpoint()
#       5
#       6 hasil = angka * diskon
#
# 200

# %%
angka = 10
diskon = 20

hasil = angka * diskon

print(hasil)

# %%
import logging
logging.basicConfig(
    level=logging.INFO,
    force=True
)

logging.info("Program dimulai")

nama = "Harvey"

logging.info(f"Nama = {nama}")

umur = 14

logging.info(f"Umur = {umur}")

logging.warning("Warning")
logging.error("Error")
