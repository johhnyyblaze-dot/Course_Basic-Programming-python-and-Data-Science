# %% [markdown]
# Klasifikasi

# %%
#Import

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline

# %%
#Baca Data

df=pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
print(df.isnull().sum())
print(df.info())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# None

# %%
x = df.drop("Outcome", axis =1)
y = df["Outcome"]

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_907/141774932.py in <cell line: 0>()
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(
#       2     x,
#       3     y,
#       4     test_size=0.2,
#       5     random_state=42
#
# NameError: name 'train_test_split' is not defined

# %%
model = DecisionTreeClassifier(
    criterion="gini",
    max_depth=4,
    random_state=42
)

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=42)

# %%
y_pred = model.predict(x_test)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.6948051948051948

# %%
pasien_baru = pd.DataFrame({
    "Pregnancies":[5],
    "Glucose":[166],
    "BloodPressure":[72],
    "SkinThickness":[35],
    "Insulin":[0],
    "BMI":[33.6],
    "DiabetesPedigreeFunction":[0.627],
    "Age":[50]
})

hasil_prediksi = model.predict(pasien_baru)
print(hasil_prediksi)
if hasil == 0:
    print("Pasien Tidak Mengidap Diabetes")
else:
    print("Pasien Mengidap Diabetes")
# Out:
# [1]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2893/2520293999.py in <cell line: 0>()
#      12 hasil_prediksi = model.predict(pasien_baru)
#      13 print(hasil_prediksi)
# ---> 14 if hasil == 0:
#      15     print("Pasien Tidak Mengidap Diabetes")
#      16 else:
#
# NameError: name 'hasil' is not defined

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(10, 8))
plot_tree(model, filled=True, feature_names=x.columns,fontsize=10,class_names=["Tidak Diabetes","Diabetes"])
plt.show()
