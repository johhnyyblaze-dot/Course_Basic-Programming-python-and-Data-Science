# %%
import pandas as pd
import numpy as np

# %%
#Membuat Series

nilai = pd.Series([90,85,75,100])
print(nilai)
# Out:
# 0     90
# 1     85
# 2     75
# 3    100
# dtype: int64

# %%
nama = pd.Series(["Andi","Budi","Ayam"])
print(nama)
# Out:
# 0    Andi
# 1    Budi
# 2    Ayam
# dtype: object

# %%
#Membuat Data Frame

data = {
    "Nama":["Andi","Budi","Ayam"],
    "Umur":[20,21,22],
    "Kota":["Medan","Jakarta","Bandung"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Nama  Umur     Kota
# 0  Andi    20    Medan
# 1  Budi    21  Jakarta
# 2  Ayam    22  Bandung

# %%
#Membaca dataset

df = pd.read_csv("StudyCase - Anggota_Perpus.csv")
print(df)

#Mencari Informasi terkait Data

df.head()
df.tail()
df.info()
df.describe()
# Out:
#       ID_Anggota Nama_Anggota                        Alamat       No.Telepon
# 0         123876      Abagael              Garibaldi Avenue   (021) - 428604
# 1         123877      Abagail                         81 St   (021) - 428605
# 2         123878         Abbe                        Elm Dr   (021) - 428606
# 3         123879        Abbey                        193 St   (021) - 428607
# 4         123880         Abbi              Fairchild Avenue   (021) - 428608
# ...          ...          ...                           ...              ...
# 3700      127576         Nata            Southern Boulevard  (021) - 5645777
# 3701      127577       Natala  Monsignor Paul M Andrews Way  (021) - 5645778
# 3702      127578      Natalee                     Waring Av  (021) - 5645779
# 3703      127579      Natalia                     Boston Rd  (021) - 5645780
# 3704      127580      Natalie                         53 Av  (021) - 5645781
#
# [3705 rows x 4 columns]
# ...

# %%
#Mengakses Data

df["Nama_Anggota"]
df[["Alamat","No.Telepon"]]
df.iloc[0]
df.iloc[0:5]
df.loc[0]
# Out:
# ID_Anggota                123876
# Nama_Anggota             Abagael
# Alamat          Garibaldi Avenue
# No.Telepon        (021) - 428604
# Name: 0, dtype: object

# %%
df.drop("Nama_Anggota",axis=1)

df.rename(columns={
    "Nama_Anggota":"Name"
})
# Out:
#       ID_Anggota     Name                        Alamat       No.Telepon
# 0         123876  Abagael              Garibaldi Avenue   (021) - 428604
# 1         123877  Abagail                         81 St   (021) - 428605
# 2         123878     Abbe                        Elm Dr   (021) - 428606
# 3         123879    Abbey                        193 St   (021) - 428607
# 4         123880     Abbi              Fairchild Avenue   (021) - 428608
# ...          ...      ...                           ...              ...
# 3700      127576     Nata            Southern Boulevard  (021) - 5645777
# 3701      127577   Natala  Monsignor Paul M Andrews Way  (021) - 5645778
# 3702      127578  Natalee                     Waring Av  (021) - 5645779
# 3703      127579  Natalia                     Boston Rd  (021) - 5645780
# 3704      127580  Natalie                         53 Av  (021) - 5645781
#
# [3705 rows x 4 columns]

# %%
df.duplicated()

df.drop_duplicates()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3700    False
# 3701    False
# 3702    False
# 3703    False
# 3704    False
# Length: 3705, dtype: bool

# %%
#Menangani Missing Value

df.isnull()
# Out:
#       ID_Anggota  Nama_Anggota  Alamat  No.Telepon
# 0          False         False   False       False
# 1          False         False   False       False
# 2          False         False   False       False
# 3          False         False   False       False
# 4          False         False   False       False
# ...          ...           ...     ...         ...
# 3700       False         False   False       False
# 3701       False         False   False       False
# 3702       False         False   False       False
# 3703       False         False   False       False
# 3704       False         False   False       False
#
# [3705 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# ID_Anggota      0
# Nama_Anggota    0
# Alamat          0
# No.Telepon      0
# dtype: int64

# %%
#Menangani Nilai Duplikat

df("No.Telepon") = df["No.Telepon"].fillna(
    df["No.Telepon"].mean()
)
# Out:
#   File "/tmp/ipykernel_385/638089328.py", line 3
#     df("No.Telepon") = df["No.Telepon"].fillna(
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?
